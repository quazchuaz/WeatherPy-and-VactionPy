# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 602

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = (requests.get(city_url)).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | east london
# Processing Record 2 of Set 1 | taoudenni
# Processing Record 3 of Set 1 | hawaiian paradise park
# Processing Record 4 of Set 1 | papatowai
# Processing Record 5 of Set 1 | nova sintra
# Processing Record 6 of Set 1 | lerwick
# Processing Record 7 of Set 1 | haiku-pauwela
# Processing Record 8 of Set 1 | queenstown
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | tolanaro
# Processing Record 11 of Set 1 | wakkanai
# Processing Record 12 of Set 1 | saint-pierre
# Processing Record 13 of Set 1 | nuku'alofa
# Processing Record 14 of Set 1 | edinburgh of the seven seas
# Processing Record 15 of Set 1 | nadym
# Processing Record 16 of Set 1 | adamstown
# Processing Record 17 of Set 1 | waitangi
# Processing Record 18 of Set 1 | nyala
# Processing Record 19 of Set 1 | walvis bay
# Processing Record 20 of Set 1 | college
# Processing Record 21 of Set 1 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 22 of Set 1 | dawson creek
# Processing Record 23 of Set 1 | arraial do cabo
# Processing Record 24 of Set 1 | rikaze
# Processing Record 25 of Set 1 | rudsar
# Processing Record 26 of Set 1 | loiza
# Processing Record 27 of Set 1 | invercargill
# Processing Record 28 of Set 1 | tazovsky
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | canto do buriti
# Processing Record 31 of Set 1 | luderitz
# Processing Record 32 of Set 1 | pirallahi
# Processing Record 33 of Set 1 | keflavik
# Processing Record 34 of Set 1 | blackmans bay
# Processing Record 35 of Set 1 | margaret river
# Processing Record 36 of Set 1 | pisco
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | ilulissat
# Processing Record 39 of Set 1 | puerto penasco
# Processing Record 40 of Set 1 | graaff-reinet
# Processing Record 41 of Set 1 | rawson
# Processing Record 42 of Set 1 | seogwipo
# City not found. Skipping...
# Processing Record 43 of Set 1 | ust-nera
# Processing Record 44 of Set 1 | cosala
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | thompson
# Processing Record 47 of Set 1 | mwingi
# Processing Record 48 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 49 of Set 1 | klyuchi
# Processing Record 50 of Set 1 | albany
# Processing Record 0 of Set 2 | ghat
# Processing Record 1 of Set 2 | lompoc
# Processing Record 2 of Set 2 | burang
# Processing Record 3 of Set 2 | tura
# Processing Record 4 of Set 2 | iqaluit
# Processing Record 5 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 6 of Set 2 | puerto natales
# Processing Record 7 of Set 2 | kingston
# Processing Record 8 of Set 2 | vilyuysk
# Processing Record 9 of Set 2 | nova olinda do norte
# Processing Record 10 of Set 2 | grytviken
# Processing Record 11 of Set 2 | ribeira grande
# Processing Record 12 of Set 2 | ixtapa
# Processing Record 13 of Set 2 | bontang
# Processing Record 14 of Set 2 | whakatane
# Processing Record 15 of Set 2 | buala
# Processing Record 16 of Set 2 | lorengau
# Processing Record 17 of Set 2 | kolonia town
# Processing Record 18 of Set 2 | dajal
# Processing Record 19 of Set 2 | olonkinbyen
# Processing Record 20 of Set 2 | alice springs
# Processing Record 44 of Set 3 | bonao
# Processing Record 45 of Set 3 | nar'yan-mar
# Processing Record 46 of Set 3 | pirane
# Processing Record 47 of Set 3 | morehead city
# Processing Record 48 of Set 3 | goleniow
# Processing Record 49 of Set 3 | anadyr
# Processing Record 0 of Set 4 | les anglais
# Processing Record 1 of Set 4 | punta arenas
# Processing Record 2 of Set 4 | san mariano
# Processing Record 3 of Set 4 | holmsund
# Processing Record 4 of Set 4 | labuan
# Processing Record 5 of Set 4 | at tall al kabir
# Processing Record 6 of Set 4 | smilavicy
# City not found. Skipping...
# Processing Record 7 of Set 4 | auki
# Processing Record 8 of Set 4 | qaqortoq
# Processing Record 9 of Set 4 | cidreira
# Processing Record 10 of Set 4 | tupiza
# Processing Record 11 of Set 4 | papao
# Processing Record 12 of Set 4 | kirov
# Processing Record 13 of Set 4 | nalut
# Processing Record 14 of Set 4 | enewetak
# Processing Record 15 of Set 4 | merowe
# Processing Record 16 of Set 4 | kruisfontein
# Processing Record 17 of Set 4 | san luis de la loma
# Processing Record 18 of Set 4 | puerto ayora
# Processing Record 19 of Set 4 | beloyarskiy
# Processing Record 20 of Set 4 | northam
# Processing Record 21 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 22 of Set 4 | hamilton
# Processing Record 23 of Set 4 | georgetown
# Processing Record 24 of Set 4 | arkhangel'sk
# Processing Record 25 of Set 4 | san andres
# Processing Record 26 of Set 4 | ushuaia
# Processing Record 27 of Set 4 | port blair
# Processing Record 28 of Set 4 | qamdo
# Processing Record 29 of Set 4 | souillac
# Processing Record 30 of Set 4 | tataouine
# Processing Record 31 of Set 4 | antsiranana
# Processing Record 32 of Set 4 | ca mau
# Processing Record 33 of Set 4 | whitehorse
# Processing Record 34 of Set 4 | stanthorpe
# Processing Record 35 of Set 4 | strelka
# Processing Record 36 of Set 4 | lazaro cardenas
# Processing Record 37 of Set 4 | magong
# Processing Record 38 of Set 4 | nouadhibou
# Processing Record 39 of Set 4 | anahuac
# Processing Record 40 of Set 4 | iskateley
# Processing Record 41 of Set 4 | laohekou
# Processing Record 42 of Set 4 | hadithah
# Processing Record 43 of Set 4 | ban dung
# Processing Record 44 of Set 4 | manokwari
# Processing Record 45 of Set 4 | empalme
# Processing Record 46 of Set 4 | dudinka
# Processing Record 47 of Set 4 | utrik
# Processing Record 48 of Set 4 | gaigeturi
# Processing Record 49 of Set 4 | canton
# Processing Record 0 of Set 5 | rebrikha
# Processing Record 1 of Set 5 | ghanzi
# Processing Record 2 of Set 5 | solnechnyy
# Processing Record 3 of Set 5 | parang
# Processing Record 4 of Set 5 | santa ana pacueco
# Processing Record 5 of Set 5 | longmen
# Processing Record 6 of Set 5 | pimentel
# Processing Record 7 of Set 5 | hotan
# Processing Record 8 of Set 5 | bouna
# Processing Record 9 of Set 5 | aasiaat
# Processing Record 10 of Set 5 | victoria point
# Processing Record 11 of Set 5 | hermanus
# Processing Record 12 of Set 5 | port douglas
# Processing Record 13 of Set 5 | codrington
# Processing Record 14 of Set 5 | afaahiti
# Processing Record 15 of Set 5 | makhambet
# Processing Record 16 of Set 5 | zarghun shahr
# Processing Record 17 of Set 5 | bubaque
# Processing Record 18 of Set 5 | yellowknife
# Processing Record 19 of Set 5 | aberdeen
# Processing Record 20 of Set 5 | winnemucca
# Processing Record 21 of Set 5 | carnarvon
# Processing Record 22 of Set 5 | laojunmiao
# Processing Record 23 of Set 5 | kailua-kona
# Processing Record 24 of Set 5 | gargalianoi
# Processing Record 25 of Set 5 | belyy yar
# Processing Record 26 of Set 5 | sarandi
# Processing Record 27 of Set 5 | labytnangi
# Processing Record 28 of Set 5 | el calafate
# Processing Record 29 of Set 5 | conduaga
# Processing Record 30 of Set 5 | huai khot
# Processing Record 31 of Set 5 | hithadhoo
# Processing Record 32 of Set 5 | happy valley-goose bay
# Processing Record 33 of Set 5 | mount gambier
# Processing Record 34 of Set 5 | gadzhiyevo
# Processing Record 35 of Set 5 | nuuk
# Processing Record 36 of Set 5 | korgun
# Processing Record 37 of Set 5 | estes park
# Processing Record 38 of Set 5 | askiz
# Processing Record 39 of Set 5 | kokofata
# City not found. Skipping...
# Processing Record 40 of Set 5 | dryden
# Processing Record 41 of Set 5 | seminole
# Processing Record 42 of Set 5 | ranot
# Processing Record 43 of Set 5 | north bend
# Processing Record 44 of Set 5 | kerikeri
# Processing Record 45 of Set 5 | asifabad
# Processing Record 46 of Set 5 | coquimbo
# Processing Record 47 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 48 of Set 5 | pathein
# Processing Record 49 of Set 5 | kone
# Processing Record 0 of Set 6 | agadez
# Processing Record 1 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 6 | remire-montjoly
# Processing Record 3 of Set 6 | uturoa
# Processing Record 4 of Set 6 | vennesla
# Processing Record 5 of Set 6 | manhattan
# Processing Record 6 of Set 6 | selfoss
# Processing Record 7 of Set 6 | kolonia
# Processing Record 8 of Set 6 | curitibanos
# Processing Record 9 of Set 6 | mount isa
# Processing Record 10 of Set 6 | hayma'
# City not found. Skipping...
# Processing Record 11 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 12 of Set 6 | salalah
# Processing Record 13 of Set 6 | siquijor
# Processing Record 14 of Set 6 | crane
# Processing Record 15 of Set 6 | plastun
# Processing Record 16 of Set 6 | fort wellington
# Processing Record 17 of Set 6 | banjarmasin
# Processing Record 18 of Set 6 | mahanoro
# Processing Record 19 of Set 6 | grootfontein
# Processing Record 20 of Set 6 | columbia falls
# Processing Record 21 of Set 6 | petrovsk-zabaykal'skiy
# Processing Record 22 of Set 6 | ratnagiri
# Processing Record 23 of Set 6 | puerto aysen
# Processing Record 24 of Set 6 | taltal
# Processing Record 25 of Set 6 | motygino
# Processing Record 26 of Set 6 | kurchatov
# Processing Record 27 of Set 6 | khandyga
# Processing Record 28 of Set 6 | la'ie
# Processing Record 29 of Set 6 | hasaki
# Processing Record 30 of Set 6 | yangjiang
# Processing Record 31 of Set 6 | topchikha
# Processing Record 32 of Set 6 | argo
# Processing Record 33 of Set 6 | ellsworth
# Processing Record 34 of Set 6 | st. john's
# Processing Record 35 of Set 6 | port lincoln
# Processing Record 36 of Set 6 | san-pedro
# Processing Record 37 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 38 of Set 6 | ahau
# City not found. Skipping...
# Processing Record 39 of Set 6 | san patricio
# Processing Record 40 of Set 6 | rasshevatskaya
# Processing Record 41 of Set 6 | okha
# Processing Record 42 of Set 6 | vorkuta
# Processing Record 43 of Set 6 | freetown
# Processing Record 44 of Set 6 | salinas
# Processing Record 45 of Set 6 | mozarlandia
# Processing Record 46 of Set 6 | severo-yeniseyskiy
# Processing Record 47 of Set 6 | talnakh
# Processing Record 48 of Set 6 | jind
# Processing Record 49 of Set 6 | cabo san lucas
# Processing Record 0 of Set 7 | taupo
# Processing Record 1 of Set 7 | al bardiyah
# Processing Record 2 of Set 7 | wynyard
# Processing Record 3 of Set 7 | portland
# Processing Record 4 of Set 7 | mersa matruh
# Processing Record 5 of Set 7 | kirsanov
# Processing Record 6 of Set 7 | colonia general alfredo stroessner
# Processing Record 7 of Set 7 | bel ombre
# Processing Record 8 of Set 7 | yanqul
# Processing Record 9 of Set 7 | aykhal
# Processing Record 10 of Set 7 | lemvig
# Processing Record 11 of Set 7 | bucerias
# Processing Record 12 of Set 7 | puerto francisco de orellana
# Processing Record 13 of Set 7 | lautoka
# Processing Record 14 of Set 7 | robore
# Processing Record 15 of Set 7 | neftcala
# Processing Record 16 of Set 7 | as sulayyil
# Processing Record 17 of Set 7 | altagracia de orituco
# Processing Record 18 of Set 7 | sitka
# Processing Record 19 of Set 7 | popondetta
# Processing Record 20 of Set 7 | howrah
# Processing Record 21 of Set 7 | koraput
# Processing Record 22 of Set 7 | kununurra
# Processing Record 23 of Set 7 | adh dhibiyah
# City not found. Skipping...
# Processing Record 24 of Set 7 | mar del plata
# Processing Record 25 of Set 7 | menzelinsk
# Processing Record 26 of Set 7 | victorica
# Processing Record 27 of Set 7 | novopetrovskoye
# Processing Record 28 of Set 7 | korla
# Processing Record 29 of Set 7 | lan krabue
# Processing Record 30 of Set 7 | alaghsas
# Processing Record 31 of Set 7 | guichon
# Processing Record 32 of Set 7 | fauske
# Processing Record 33 of Set 7 | boguchany
# Processing Record 34 of Set 7 | kiuruvesi
# Processing Record 35 of Set 7 | yeraliyev
# Processing Record 36 of Set 7 | nova vicosa
# Processing Record 37 of Set 7 | tsumeb
# Processing Record 38 of Set 7 | porto novo
# Processing Record 39 of Set 7 | port augusta
# Processing Record 40 of Set 7 | fortuna
# Processing Record 41 of Set 7 | impfondo
# Processing Record 42 of Set 7 | aitape
# Processing Record 43 of Set 7 | glace bay
# Processing Record 44 of Set 7 | mandal
# Processing Record 45 of Set 7 | ouellah
# City not found. Skipping...
# Processing Record 46 of Set 7 | oodweyne
# Processing Record 47 of Set 7 | fale old settlement
# Processing Record 48 of Set 7 | kabalo
# Processing Record 49 of Set 7 | miguel auza
# Processing Record 0 of Set 8 | krutaya gorka
# Processing Record 1 of Set 8 | dunedin
# Processing Record 2 of Set 8 | yulinshi
# Processing Record 3 of Set 8 | ocean pointe
# City not found. Skipping...
# Processing Record 4 of Set 8 | reo
# Processing Record 5 of Set 8 | akhisar
# Processing Record 26 of Set 9 | markala
# Processing Record 27 of Set 9 | onguday
# Processing Record 28 of Set 9 | bamboo flat
# Processing Record 29 of Set 9 | lake havasu city
# Processing Record 30 of Set 9 | tsiombe
# Processing Record 31 of Set 9 | jiwani
# Processing Record 32 of Set 9 | atafu village
# Processing Record 33 of Set 9 | silapathar
# Processing Record 34 of Set 9 | stornoway
# Processing Record 35 of Set 9 | tazacorte
# Processing Record 36 of Set 9 | el haouaria
# Processing Record 37 of Set 9 | knyaze-volkonskoye
# Processing Record 38 of Set 9 | la passe
# Processing Record 39 of Set 9 | ugurludag
# Processing Record 40 of Set 9 | sao gabriel da cachoeira
# Processing Record 41 of Set 9 | ketchikan
# Processing Record 42 of Set 9 | darnah
# Processing Record 43 of Set 9 | san antonio de pale
# Processing Record 44 of Set 9 | puerto lempira
# Processing Record 45 of Set 9 | dabakala
# Processing Record 46 of Set 9 | gallup
# Processing Record 47 of Set 9 | tocopilla
# Processing Record 48 of Set 9 | karratha
# Processing Record 49 of Set 9 | mejit
# Processing Record 0 of Set 10 | holualoa
# Processing Record 1 of Set 10 | bonthe
# Processing Record 2 of Set 10 | valparaiso
# Processing Record 3 of Set 10 | kataragama
# City not found. Skipping...
# Processing Record 4 of Set 10 | sao miguel do tapuio
# Processing Record 5 of Set 10 | hamburg
# Processing Record 6 of Set 10 | metlili chaamba
# Processing Record 7 of Set 10 | nanpiao
# Processing Record 8 of Set 10 | fiambala
# Processing Record 9 of Set 10 | suoyarvi
# Processing Record 10 of Set 10 | ta`u
# Processing Record 11 of Set 10 | kashgar
# Processing Record 12 of Set 10 | khewra
# Processing Record 13 of Set 10 | port shepstone
# Processing Record 14 of Set 10 | usinsk
# Processing Record 15 of Set 10 | rongelap
# Processing Record 16 of Set 10 | wanganui
# Processing Record 17 of Set 10 | granada
# Processing Record 18 of Set 10 | la ronge
# Processing Record 19 of Set 10 | hillsborough
# Processing Record 20 of Set 10 | along
# Processing Record 21 of Set 10 | castillos
# Processing Record 22 of Set 10 | shagonar
# Processing Record 23 of Set 10 | oliver
# Processing Record 24 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 25 of Set 10 | mogocha
# Processing Record 26 of Set 10 | grand-bassam
# Processing Record 27 of Set 10 | saint-paul
# Processing Record 28 of Set 10 | mansa
# Processing Record 29 of Set 10 | shimoda
# Processing Record 30 of Set 10 | al burayqah
# Processing Record 31 of Set 10 | vadso
# Processing Record 32 of Set 10 | taourirt
# Processing Record 33 of Set 10 | khorixas
# Processing Record 34 of Set 10 | independence
# Processing Record 35 of Set 10 | pemba
# Processing Record 36 of Set 10 | vila franca do campo
# Processing Record 37 of Set 10 | loyew
# Processing Record 38 of Set 10 | pandan
# Processing Record 39 of Set 10 | hadibu
# Processing Record 40 of Set 10 | wacheng
# Processing Record 41 of Set 10 | yuncheng
# Processing Record 42 of Set 10 | kazan
# Processing Record 43 of Set 10 | kaffrine
# Processing Record 44 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 45 of Set 10 | zapfendorf
# Processing Record 46 of Set 10 | rio grande
# Processing Record 47 of Set 10 | chandler
# Processing Record 48 of Set 10 | mahabe
# City not found. Skipping...
# Processing Record 49 of Set 10 | sawa sawa
# Processing Record 0 of Set 11 | novyy urengoy
# Processing Record 1 of Set 11 | kristiansund
# Processing Record 2 of Set 11 | kyren
# Processing Record 3 of Set 11 | carnot
# Processing Record 4 of Set 11 | tomatlan
# Processing Record 5 of Set 11 | yeniseysk
# Processing Record 6 of Set 11 | chos malal
# Processing Record 7 of Set 11 | bisbee
# Processing Record 8 of Set 11 | brokopondo
# Processing Record 9 of Set 11 | timimoun
# Processing Record 10 of Set 11 | namdrik
# Processing Record 11 of Set 11 | touros
# Processing Record 12 of Set 11 | island harbour
# Processing Record 13 of Set 11 | dauphin
# Processing Record 14 of Set 11 | palikir - national government center
# Processing Record 15 of Set 11 | weno
# Processing Record 16 of Set 11 | bairnsdale
# Processing Record 17 of Set 11 | salekhard
# Processing Record 18 of Set 11 | omsk
# Processing Record 19 of Set 11 | sechura
# Processing Record 20 of Set 11 | tual
# Processing Record 21 of Set 11 | ancud
# Processing Record 22 of Set 11 | alo
# Processing Record 23 of Set 11 | palangkaraya
# Processing Record 24 of Set 11 | baoying
# Processing Record 25 of Set 11 | menuma
# Processing Record 26 of Set 11 | saint-joseph
# Processing Record 27 of Set 11 | qarqaraly
# Processing Record 28 of Set 11 | kichmengskiy gorodok
# Processing Record 29 of Set 11 | princeville
# Processing Record 30 of Set 11 | biltine
# Processing Record 31 of Set 11 | camacupa
# Processing Record 32 of Set 11 | khash
# Processing Record 33 of Set 11 | balykshi
# Processing Record 34 of Set 11 | mana
# Processing Record 35 of Set 11 | posto fiscal rolim de moura
# Processing Record 36 of Set 11 | duyun
# Processing Record 37 of Set 11 | senillosa
# Processing Record 38 of Set 11 | alpena
# Processing Record 39 of Set 11 | plonsk
# Processing Record 40 of Set 11 | piney green
# Processing Record 41 of Set 11 | beledweyne
# Processing Record 42 of Set 11 | pemangkat
# Processing Record 43 of Set 11 | changping
# Processing Record 44 of Set 11 | francisco sa
# Processing Record 45 of Set 11 | kudymkar
# Processing Record 46 of Set 11 | illizi
# Processing Record 47 of Set 11 | tuscania
# Processing Record 48 of Set 11 | bulacan
# Processing Record 49 of Set 11 | rossleben
# Processing Record 0 of Set 12 | aldan
# Processing Record 1 of Set 12 | ocean shores
# Processing Record 2 of Set 12 | jacksonville
# Processing Record 3 of Set 12 | naze
# Processing Record 4 of Set 12 | guaiba
# Processing Record 5 of Set 12 | misratah
# Processing Record 6 of Set 12 | luebo
# Processing Record 7 of Set 12 | suva
# Processing Record 8 of Set 12 | hailar
# Processing Record 9 of Set 12 | shirdi
# Processing Record 10 of Set 12 | regina
# Processing Record 11 of Set 12 | murzuq
# Processing Record 12 of Set 12 | jiamusi
# Processing Record 13 of Set 12 | boticas
# Processing Record 14 of Set 12 | lensk
# Processing Record 15 of Set 12 | ambovombe
# Processing Record 16 of Set 12 | amga
# Processing Record 17 of Set 12 | marsh harbour
# Processing Record 18 of Set 12 | jinxiang
# Processing Record 19 of Set 12 | singkil
# Processing Record 20 of Set 12 | krasnyy chikoy
# Processing Record 21 of Set 12 | kirensk
# Processing Record 22 of Set 12 | masterton
# Processing Record 23 of Set 12 | taro
# Processing Record 24 of Set 12 | westport
# Processing Record 25 of Set 12 | sanctuary point
# Processing Record 26 of Set 12 | qapqal
# City not found. Skipping...
# Processing Record 27 of Set 12 | miches
# Processing Record 28 of Set 12 | najaf
# Processing Record 29 of Set 12 | amasra
# Processing Record 30 of Set 12 | brookings
# Processing Record 31 of Set 12 | sideropolis
# Processing Record 32 of Set 12 | taikang
# Processing Record 33 of Set 12 | kayangel
# Processing Record 34 of Set 12 | laminusa
# Processing Record 35 of Set 12 | maintirano
# Processing Record 36 of Set 12 | tangalle
# Processing Record 37 of Set 12 | tabou
# Processing Record 38 of Set 12 | smithers
# Processing Record 39 of Set 12 | katsuura
# Processing Record 40 of Set 12 | mishan
# Processing Record 41 of Set 12 | enniskillen
# Processing Record 42 of Set 12 | benjamin constant
# Processing Record 43 of Set 12 | cide
# Processing Record 44 of Set 12 | katsuren-haebaru
# Processing Record 45 of Set 12 | kapuskasing
# Processing Record 46 of Set 12 | trikala
# Processing Record 47 of Set 12 | sola
# Processing Record 48 of Set 12 | basco
# Processing Record 49 of Set 12 | tranas
# Processing Record 0 of Set 13 | turaif
# Processing Record 1 of Set 13 | minas de marcona
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather
# Out:
# {'coord': {'lon': -75.1103, 'lat': -15.2119},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 15.72,
#   'feels_like': 15.12,
#   'temp_min': 15.72,
#   'temp_max': 15.72,
#   'pressure': 1014,
#   'humidity': 68,
#   'sea_level': 1014,
#   'grnd_level': 926},
#  'visibility': 10000,
#  'wind': {'speed': 4.55, 'deg': 144, 'gust': 4.56},
#  'clouds': {'all': 91},
#  'dt': 1689345648,
#  'sys': {'country': 'PE', 'sunrise': 1689334031, 'sunset': 1689374697},
#  'timezone': -18000,
#  'id': 3935288,
#  'name': 'Minas de Marcona',
#  'cod': 200}

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
# Display sample data
city_data_df.head()

city_data_df["Date"]=(pd.to_datetime(city_data_df["Date"],unit='s')).dt.date
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             east london -33.0153   27.9116     20.52        68           0
# 1               taoudenni  22.6783   -3.9836     46.04         3           5
# 2  hawaiian paradise park  19.5933 -154.9731     22.24        90         100
# 3               papatowai -46.5619  169.4708     10.08        84          88
# 4             nova sintra  14.8667  -24.7167     23.63        81          45
#
#    Wind Speed Country        Date
# 0        1.54      ZA  2023-07-14
# 1        9.74      ML  2023-07-14
# 2        3.09      US  2023-07-14
# 3        5.49      NZ  2023-07-14
# 4        2.89      CV  2023-07-14

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                   east london -33.0153   27.9116     20.52        68
# 1                     taoudenni  22.6783   -3.9836     46.04         3
# 2        hawaiian paradise park  19.5933 -154.9731     22.24        90
# 3                     papatowai -46.5619  169.4708     10.08        84
# 4                   nova sintra  14.8667  -24.7167     23.63        81
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 0        1.54      ZA  2023-07-14
# 1                 5        9.74      ML  2023-07-14
# 2               100        3.09      US  2023-07-14
# 3                88        5.49      NZ  2023-07-14
# 4                45        2.89      CV  2023-07-14

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], alpha=.9, edgecolors="k")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature °C")
date=city_data_df["Date"].min()
plt.title(f"City Max Latitude vs. Temperature ({date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], alpha=.9, edgecolors="k")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
date=city_data_df["Date"].min()
plt.title(f"City Latitude vs. Humidity ({date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], alpha=.9, edgecolors="k")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
date=city_data_df["Date"].min()
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], alpha=.9, edgecolors="k")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
date=city_data_df["Date"].min()
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

#(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#regress_values = x_values * slope + intercept

#equation of a line, y = mx + c
#line = f"y = (round(slope,2))x + (round(intercept,2))"

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
north_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) > 0, :]

# Display sample data
north_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                     taoudenni  22.6783   -3.9836     46.04         3
# 2        hawaiian paradise park  19.5933 -154.9731     22.24        90
# 4                   nova sintra  14.8667  -24.7167     23.63        81
# 5                       lerwick  60.1545   -1.1494     16.00        78
# 6                 haiku-pauwela  20.9219 -156.3051     23.36        79
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                 5        9.74      ML  2023-07-14
# 2               100        3.09      US  2023-07-14
# 4                45        2.89      CV  2023-07-14
# 5                43        4.22      GB  2023-07-14
# 6                20        4.63      US  2023-07-14

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
south_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) < 0, :]

# Display sample data
south_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              east london -33.0153   27.9116     20.52        68           0
# 3                papatowai -46.5619  169.4708     10.08        84          88
# 7               queenstown -31.8976   26.8753     14.66        32          69
# 8        port-aux-francais -49.3500   70.2167      2.78        59          93
# 9                 tolanaro -25.0319   46.9987     20.04        68          75
#
#          Wind Speed Country        Date
# City_ID
# 0              1.54      ZA  2023-07-14
# 3              5.49      NZ  2023-07-14
# 7              3.02      ZA  2023-07-14
# 8             13.66      TF  2023-07-14
# 9              3.09      MG  2023-07-14

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = north_hemi_df["Lat"]
y_values = north_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(line,(0,15),fontsize=15,color="red")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is -0.6449646377712098

# %%
# Linear regression on Southern Hemisphere
x_values = south_hemi_df["Lat"]
y_values = south_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(line,(-30,5),fontsize=15,color="red")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.8702188667120985

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = north_hemi_df["Lat"]
y_values = north_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line,(0,15),fontsize=15,color="red")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.023837034556547527

# %%
# Southern Hemisphere
x_values = south_hemi_df["Lat"]
y_values = south_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line,(-50, 20),fontsize=15,color="red")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is -0.11464739577867093

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = north_hemi_df["Lat"]
y_values = north_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line,(0,15),fontsize=15,color="red")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is -0.030039059163308176

# %%
# Southern Hemisphere
x_values = south_hemi_df["Lat"]
y_values = south_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line,(-50,15),fontsize=15,color="red")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is -0.08541668961637702

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = north_hemi_df["Lat"]
y_values = north_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line,(0,12),fontsize=15,color="red")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is -0.14689308005685656

# %%
# Southern Hemisphere
x_values = south_hemi_df["Lat"]
y_values = south_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line = f"y = {round(slope,3)}x + {round(intercept,3)}"

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line,(-50,12),fontsize=15,color="red")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.021634113557723187

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
